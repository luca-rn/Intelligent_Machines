# %% [markdown]
# <a href="https://colab.research.google.com/github/luca-rn/Intelligent_Machines/blob/main/RCNNCardVision2Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import transforms
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from PIL import Image
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T

# %%
from google.colab import drive
drive.mount('/content/drive')

zip_path = '/content/drive/MyDrive/data-yolo.zip'
# Out:
# Mounted at /content/drive

# %%
import shutil
import os
import zipfile

# extract zip file
download_folder = "/content"
zip_name = "data-yolo.zip"
os.makedirs(download_folder, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(download_folder)

print(f"Extraction complete! Files saved to {download_folder}")
# Out:
# Extraction complete! Files saved to /content

# %%
# split data into training and validation, still in yolo format

import os
import shutil
import random

# Paths
dataset_path = download_folder
image_dir = os.path.join(dataset_path, "images")
label_dir = os.path.join(dataset_path, "labels")

# Output paths
train_img = os.path.join(dataset_path, "images/train")
val_img = os.path.join(dataset_path, "images/val")
train_lbl = os.path.join(dataset_path, "yolo/labels/train")
val_lbl = os.path.join(dataset_path, "yolo/labels/val")

# Create train/val folders
for d in [train_img, val_img, train_lbl, val_lbl]:
    os.makedirs(d, exist_ok=True)

# List images and shuffle
images = sorted([f for f in os.listdir(image_dir) if f.endswith(".jpg")])  # Adjust for other image formats
random.shuffle(images)

# Split 80% train, 20% val
split_idx = int(0.8 * len(images))
train_files, val_files = images[:split_idx], images[split_idx:]

# Move files
for file_list, img_dest, lbl_dest in [(train_files, train_img, train_lbl), (val_files, val_img, val_lbl)]:
    for file in file_list:
        shutil.move(os.path.join(image_dir, file), os.path.join(img_dest, file))
        label_file = file.replace(".jpg", ".txt")  # Assuming YOLO format
        if os.path.exists(os.path.join(label_dir, label_file)):
            shutil.move(os.path.join(label_dir, label_file), os.path.join(lbl_dest, label_file))

print("Dataset successfully split into training and validation sets!")

yolo_train_labels = train_lbl
yolo_val_labels = val_lbl
# Out:
# Dataset successfully split into training and validation sets!

# %%
# Converting from YOLO annotations to annotations for Faster RCNN

import os
import json
import glob
from PIL import Image

#classes = ["Exploding Kittens", "Munchkin", "Poker", "Uno"]

rcnn_train_labels = os.path.join(dataset_path, "labels/train")
rcnn_val_labels = os.path.join(dataset_path, "labels/val")

# Create directories if they don't exist
os.makedirs(rcnn_train_labels, exist_ok=True)
os.makedirs(rcnn_val_labels, exist_ok=True)

def yolo_to_rcnn_bbox(x_center, y_center, width, height, img_w, img_h):
    x_center *= img_w
    y_center *= img_h
    width *= img_w
    height *= img_h

    x_min = x_center - width / 2
    y_min = y_center - height / 2
    x_max = x_center + width / 2
    y_max = y_center + height / 2

    return [x_min, y_min, x_max, y_max]


def convert_yolo_folder_to_rcnn(yolo_folder,img_folder,out_folder):
  for label_file in os.listdir(yolo_folder):
    if not label_file.endswith('.txt'):
        continue

    img_name = label_file.replace('.txt', '.jpg')
    img_path = os.path.join(img_folder, img_name)
    label_path = os.path.join(yolo_folder, label_file)

    if not os.path.exists(img_path):
        print(f"Image not found for {label_file}, skipping.")
        continue

    img = Image.open(img_path)
    img_w, img_h = img.size

    with open(label_path, 'r') as f:
        lines = f.readlines()

    rcnn_lines = []
    for line in lines:
      class_id, x_c, y_c, w, h = map(float, line.strip().split())
      x_min, y_min, x_max, y_max = yolo_to_rcnn_bbox(x_c, y_c, w, h, img_w, img_h)
      rcnn_lines.append(f"{int(class_id)} {x_min} {y_min} {x_max} {y_max}")

    output_file = os.path.join(out_folder, label_file)
    with open(output_file, 'w') as f:
      f.write("\n".join(rcnn_lines))

    print(f'Converted labels from {yolo_folder} to {out_folder}')
  return out_folder

train_lbl = convert_yolo_folder_to_rcnn(yolo_train_labels, train_img, rcnn_train_labels)
val_lbl = convert_yolo_folder_to_rcnn(yolo_val_labels, val_img, rcnn_val_labels)
# Out:
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/train to /content/labels/train
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val
# Converted labels from /content/yolo/labels/val to /content/labels/val

# %%
# Read class names from classes.txt
classes_txt_path = os.path.join(dataset_path, "classes.txt")
with open(classes_txt_path, "r") as f:
    class_names = [line.strip() for line in f.readlines()]
# Generate dataset.yaml
dataset_yaml_path = os.path.join(dataset_path, "dataset.yaml")
with open(dataset_yaml_path, "w") as f:
    f.write(f"train: {train_img}\n")
    f.write(f"val: {val_img}\n")
    f.write(f"nc: {len(class_names)}\n")
    f.write(f"names: {class_names}\n")

print('\nFile contents:\n')
# !cat /content/dataset.yaml
# Out:
# File contents:
#
# train: /content/images/train
# val: /content/images/val
# nc: 4
# names: ['Exploding Kittens', 'Munchkin', 'Poker', 'Uno']

# %%
import yaml
from torchvision.transforms import functional as F
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import matplotlib.pyplot as plt

# 1️⃣ Parse your dataset.yaml
with open(dataset_yaml_path, 'r') as f:
    cfg = yaml.safe_load(f)
train_img_dir = cfg['train']
val_img_dir   = cfg['val']
num_classes   = cfg['nc'] + 1        # +1 for background class
class_names   = cfg['names']

train_lbl_dir = rcnn_train_labels
val_lbl_dir   = rcnn_val_labels

# %%
from torchvision.transforms import functional as F
import torchvision.transforms as T

def get_transforms(train):
    transforms = []
    # Converts PIL image to Tensor
    transforms.append(T.ToTensor())
    # You can add data augmentation here for training
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

class CardDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transforms=None):
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.transforms = transforms
        # List of image filenames
        self.imgs = sorted([f for f in os.listdir(images_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))])

    def __getitem__(self, idx):
        img_filename = self.imgs[idx]
        img_path = os.path.join(self.images_dir, img_filename)
        label_path = os.path.join(self.labels_dir, os.path.splitext(img_filename)[0] + '.txt')

        # Load image
        img = Image.open(img_path).convert("RGB")

        # Parse annotation file
        boxes = []
        labels = []
        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                cls = int(parts[0])
                x_min, y_min, x_max, y_max = map(float, parts[1:])
                boxes.append([x_min, y_min, x_max, y_max])
                labels.append(cls)

        # Convert to tensors
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        iscrowd = torch.zeros((len(labels),), dtype=torch.int64)

        target = {
            'boxes': boxes,
            'labels': labels,
            'image_id': image_id,
            'area': area,
            'iscrowd': iscrowd
        }

        if self.transforms:
            img = self.transforms(img)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
# Collate function needed for batching variable-size targets
def collate_fn(batch):
    return tuple(zip(*batch))

train_ds = CardDataset(train_img_dir, train_lbl_dir, transforms=get_transforms(True))
val_ds   = CardDataset(val_img_dir,   val_lbl_dir,   transforms=get_transforms(False))

from torchvision.ops import misc as misc_ops
DataLoader = torch.utils.data.DataLoader

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_loader   = DataLoader(val_ds,   batch_size=2, shuffle=False, collate_fn=collate_fn)

# %%
# Device setup
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
in_f = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_f, num_classes)
model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum = 0.9, weight_decay=1e-4)
#lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
lr_scheduler2 = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20,35,50], gamma=0.5)

# %%
# Training and validation loops
def train_one_epoch(model, optimizer, data_loader, device, epoch):
    model.train()
    total_loss = 0.0
    for images, targets in data_loader:
        images = list(img.to(device) for img in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        total_loss += loss_value

    avg_loss = total_loss / len(data_loader)
    print(f"Epoch {epoch+1} Training -- Total Loss: {total_loss:.4f}, Average Loss: {avg_loss:.4f}")
    return total_loss, avg_loss

# %%
def validate(model, data_loader, device, epoch):
    model.eval()
    total_val_loss = 0.0
    with torch.no_grad():
        for images, targets in data_loader:
            images = list(img.to(device) for img in images)
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            model.train()
            loss_dict = model(images, targets)
            model.eval()
            losses = sum(loss for loss in loss_dict.values())
            total_val_loss += losses.item()
    avg_val_loss = total_val_loss / len(data_loader)
    print(f"Epoch {epoch+1} Validation -- Total Loss: {total_val_loss:.4f}, Average Loss: {avg_val_loss:.4f}")
    return total_val_loss, avg_val_loss

# %%
# Run training
epochs = 60
training_stats = []
for epoch in range(epochs):
    train_total, train_avg = train_one_epoch(model, optimizer, train_loader, device, epoch)
    val_total, val_avg = validate(model, val_loader, device, epoch)
    lr_scheduler2.step()
    training_stats.append((train_total, train_avg, val_total, val_avg))

model_path = f"fasterrcnn_resnet50_epoch_{epoch+1}.pth"
torch.save(model.state_dict(), model_path)
print(f"Training completed after {epochs} epochs. Model saved: {model_path}")
# Out:
# Epoch 1 Training -- Total Loss: 9.3249, Average Loss: 0.5485
# Epoch 1 Validation -- Total Loss: 5.0222, Average Loss: 0.5580
# Epoch 2 Training -- Total Loss: 5.0675, Average Loss: 0.2981
# Epoch 2 Validation -- Total Loss: 4.5301, Average Loss: 0.5033
# Epoch 3 Training -- Total Loss: 4.8320, Average Loss: 0.2842
# Epoch 3 Validation -- Total Loss: 4.4691, Average Loss: 0.4966
# Epoch 4 Training -- Total Loss: 4.3706, Average Loss: 0.2571
# Epoch 4 Validation -- Total Loss: 3.9529, Average Loss: 0.4392
# Epoch 5 Training -- Total Loss: 3.5377, Average Loss: 0.2081
# Epoch 5 Validation -- Total Loss: 3.7974, Average Loss: 0.4219
# Epoch 6 Training -- Total Loss: 3.6045, Average Loss: 0.2120
# Epoch 6 Validation -- Total Loss: 3.9128, Average Loss: 0.4348
# Epoch 7 Training -- Total Loss: 3.5681, Average Loss: 0.2099
# Epoch 7 Validation -- Total Loss: 4.0197, Average Loss: 0.4466
# Epoch 8 Training -- Total Loss: 2.8763, Average Loss: 0.1692
# Epoch 8 Validation -- Total Loss: 3.8740, Average Loss: 0.4304
# Epoch 9 Training -- Total Loss: 3.0429, Average Loss: 0.1790
# Epoch 9 Validation -- Total Loss: 3.7988, Average Loss: 0.4221
# Epoch 10 Training -- Total Loss: 2.9185, Average Loss: 0.1717
# Epoch 10 Validation -- Total Loss: 3.7256, Average Loss: 0.4140
# Epoch 11 Training -- Total Loss: 2.4623, Average Loss: 0.1448
# Epoch 11 Validation -- Total Loss: 3.7251, Average Loss: 0.4139
# Epoch 12 Training -- Total Loss: 2.4095, Average Loss: 0.1417
# Epoch 12 Validation -- Total Loss: 3.7801, Average Loss: 0.4200
# Epoch 13 Training -- Total Loss: 2.9251, Average Loss: 0.1721
# Epoch 13 Validation -- Total Loss: 3.7842, Average Loss: 0.4205
# Epoch 14 Training -- Total Loss: 2.4221, Average Loss: 0.1425
# Epoch 14 Validation -- Total Loss: 3.7727, Average Loss: 0.4192
# Epoch 15 Training -- Total Loss: 2.1008, Average Loss: 0.1236
# Epoch 15 Validation -- Total Loss: 3.9645, Average Loss: 0.4405
# Epoch 16 Training -- Total Loss: 1.9609, Average Loss: 0.1153
# Epoch 16 Validation -- Total Loss: 3.6777, Average Loss: 0.4086
# Epoch 17 Training -- Total Loss: 1.9286, Average Loss: 0.1134
# Epoch 17 Validation -- Total Loss: 3.6891, Average Loss: 0.4099
# Epoch 18 Training -- Total Loss: 2.2927, Average Loss: 0.1349
# Epoch 18 Validation -- Total Loss: 3.6713, Average Loss: 0.4079
# Epoch 19 Training -- Total Loss: 1.9518, Average Loss: 0.1148
# Epoch 19 Validation -- Total Loss: 3.6294, Average Loss: 0.4033
# Epoch 20 Training -- Total Loss: 2.0564, Average Loss: 0.1210
# Epoch 20 Validation -- Total Loss: 3.6075, Average Loss: 0.4008
# Epoch 21 Training -- Total Loss: 1.7853, Average Loss: 0.1050
# Epoch 21 Validation -- Total Loss: 3.5076, Average Loss: 0.3897
# Epoch 22 Training -- Total Loss: 1.7106, Average Loss: 0.1006
# Epoch 22 Validation -- Total Loss: 3.5931, Average Loss: 0.3992
# Epoch 23 Training -- Total Loss: 1.3667, Average Loss: 0.0804
# Epoch 23 Validation -- Total Loss: 3.6806, Average Loss: 0.4090
# Epoch 24 Training -- Total Loss: 1.2740, Average Loss: 0.0749
# Epoch 24 Validation -- Total Loss: 3.5864, Average Loss: 0.3985
# Epoch 25 Training -- Total Loss: 1.0221, Average Loss: 0.0601
# Epoch 25 Validation -- Total Loss: 3.6014, Average Loss: 0.4002
# Epoch 26 Training -- Total Loss: 1.0494, Average Loss: 0.0617
# Epoch 26 Validation -- Total Loss: 3.6156, Average Loss: 0.4017
# Epoch 27 Training -- Total Loss: 1.1016, Average Loss: 0.0648
# Epoch 27 Validation -- Total Loss: 3.6578, Average Loss: 0.4064
# Epoch 28 Training -- Total Loss: 1.2210, Average Loss: 0.0718
# Epoch 28 Validation -- Total Loss: 3.5760, Average Loss: 0.3973
# Epoch 29 Training -- Total Loss: 1.5572, Average Loss: 0.0916
# Epoch 29 Validation -- Total Loss: 3.5446, Average Loss: 0.3938
# Epoch 30 Training -- Total Loss: 1.3128, Average Loss: 0.0772
# Epoch 30 Validation -- Total Loss: 3.4938, Average Loss: 0.3882
# Epoch 31 Training -- Total Loss: 0.9917, Average Loss: 0.0583
# Epoch 31 Validation -- Total Loss: 3.4752, Average Loss: 0.3861
# Epoch 32 Training -- Total Loss: 1.0638, Average Loss: 0.0626
# Epoch 32 Validation -- Total Loss: 3.5781, Average Loss: 0.3976
# Epoch 33 Training -- Total Loss: 1.1664, Average Loss: 0.0686
# Epoch 33 Validation -- Total Loss: 3.5278, Average Loss: 0.3920
# Epoch 34 Training -- Total Loss: 0.9482, Average Loss: 0.0558
# Epoch 34 Validation -- Total Loss: 3.5423, Average Loss: 0.3936
# Epoch 35 Training -- Total Loss: 0.8817, Average Loss: 0.0519
# Epoch 35 Validation -- Total Loss: 3.6717, Average Loss: 0.4080
# Epoch 36 Training -- Total Loss: 1.0205, Average Loss: 0.0600
# Epoch 36 Validation -- Total Loss: 3.6574, Average Loss: 0.4064
# Epoch 37 Training -- Total Loss: 0.9660, Average Loss: 0.0568
# Epoch 37 Validation -- Total Loss: 3.6226, Average Loss: 0.4025
# Epoch 38 Training -- Total Loss: 0.9474, Average Loss: 0.0557
# Epoch 38 Validation -- Total Loss: 3.6605, Average Loss: 0.4067
# Epoch 39 Training -- Total Loss: 0.8014, Average Loss: 0.0471
# Epoch 39 Validation -- Total Loss: 3.6238, Average Loss: 0.4026
# Epoch 40 Training -- Total Loss: 0.7290, Average Loss: 0.0429
# Epoch 40 Validation -- Total Loss: 3.6191, Average Loss: 0.4021
# Epoch 41 Training -- Total Loss: 0.7043, Average Loss: 0.0414
# Epoch 41 Validation -- Total Loss: 3.6547, Average Loss: 0.4061
# Epoch 42 Training -- Total Loss: 0.7171, Average Loss: 0.0422
# Epoch 42 Validation -- Total Loss: 3.6977, Average Loss: 0.4109
# Epoch 43 Training -- Total Loss: 0.5691, Average Loss: 0.0335
# Epoch 43 Validation -- Total Loss: 3.7141, Average Loss: 0.4127
# Epoch 44 Training -- Total Loss: 0.6334, Average Loss: 0.0373
# Epoch 44 Validation -- Total Loss: 3.6807, Average Loss: 0.4090
# Epoch 45 Training -- Total Loss: 0.5843, Average Loss: 0.0344
# Epoch 45 Validation -- Total Loss: 3.7016, Average Loss: 0.4113
# Epoch 46 Training -- Total Loss: 0.6919, Average Loss: 0.0407
# Epoch 46 Validation -- Total Loss: 3.7015, Average Loss: 0.4113
# Epoch 47 Training -- Total Loss: 0.5483, Average Loss: 0.0323
# Epoch 47 Validation -- Total Loss: 3.6877, Average Loss: 0.4097
# Epoch 48 Training -- Total Loss: 0.5756, Average Loss: 0.0339
# Epoch 48 Validation -- Total Loss: 3.7268, Average Loss: 0.4141
# Epoch 49 Training -- Total Loss: 0.5011, Average Loss: 0.0295
# Epoch 49 Validation -- Total Loss: 3.6649, Average Loss: 0.4072
# Epoch 50 Training -- Total Loss: 0.6267, Average Loss: 0.0369
# Epoch 50 Validation -- Total Loss: 3.7780, Average Loss: 0.4198
# Epoch 51 Training -- Total Loss: 0.5723, Average Loss: 0.0337
# Epoch 51 Validation -- Total Loss: 3.7217, Average Loss: 0.4135
# Epoch 52 Training -- Total Loss: 0.5981, Average Loss: 0.0352
# Epoch 52 Validation -- Total Loss: 3.7282, Average Loss: 0.4142
# Epoch 53 Training -- Total Loss: 0.4882, Average Loss: 0.0287
# Epoch 53 Validation -- Total Loss: 3.7165, Average Loss: 0.4129
# Epoch 54 Training -- Total Loss: 0.5192, Average Loss: 0.0305
# Epoch 54 Validation -- Total Loss: 3.7228, Average Loss: 0.4136
# Epoch 55 Training -- Total Loss: 0.5951, Average Loss: 0.0350
# Epoch 55 Validation -- Total Loss: 3.7217, Average Loss: 0.4135
# Epoch 56 Training -- Total Loss: 0.4896, Average Loss: 0.0288
# Epoch 56 Validation -- Total Loss: 3.7004, Average Loss: 0.4112
# Epoch 57 Training -- Total Loss: 0.4626, Average Loss: 0.0272
# Epoch 57 Validation -- Total Loss: 3.7263, Average Loss: 0.4140
# Epoch 58 Training -- Total Loss: 0.4361, Average Loss: 0.0257
# Epoch 58 Validation -- Total Loss: 3.7305, Average Loss: 0.4145
# Epoch 59 Training -- Total Loss: 0.5289, Average Loss: 0.0311
# Epoch 59 Validation -- Total Loss: 3.7135, Average Loss: 0.4126
# Epoch 60 Training -- Total Loss: 0.4520, Average Loss: 0.0266
# Epoch 60 Validation -- Total Loss: 3.7328, Average Loss: 0.4148
# Training completed after 60 epochs. Model saved: fasterrcnn_resnet50_epoch_60.pth

# %%
## Training Performance

import matplotlib.pyplot as plt

# Unpack stats
train_totals = []
train_avgs   = []
val_totals   = []
val_avgs     = []
for t in training_stats:
  train_totals.append(t[0])
  train_avgs.append(t[1])
  val_totals.append(t[2])
  val_avgs.append(t[3])
epochs_range = range(1, len(training_stats) + 1)

# Plot
plt.figure(figsize=(12, 6))

# Plot losses
plt.plot(epochs_range, train_totals, label='Train Total Loss', color='blue')
plt.plot(epochs_range, val_totals, label='Val Total Loss', color='red')
plt.plot(epochs_range, train_avgs, '--', label='Train Avg Loss', color='cyan')
plt.plot(epochs_range, val_avgs, '--', label='Val Avg Loss', color='orange')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training & Validation Loss over Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
CLASS_MAP = {4: "Exploding Kittens", 1: "Munchkin", 2: "Poker", 3: "Uno"}

import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def visualize_predictions(dataset, model, device, num_images=10, score_threshold=0.3):
    model.eval()
    for idx in range(min(num_images, len(dataset))):
        img, _ = dataset[idx]
        orig = img.mul(255).permute(1, 2, 0).byte().numpy()

        fig, ax = plt.subplots(1, figsize=(6,6))
        ax.imshow(orig)

        with torch.no_grad():
            pred = model([img.to(device)])[0]
        print(pred)
        # loop over boxes, labels, and scores
        for box, label, score in zip(pred['boxes'], pred['labels'], pred['scores']):
            if score.item() < score_threshold:
                continue

            x1, y1, x2, y2 = box.tolist()
            rect = patches.Rectangle(
                (x1, y1), x2 - x1, y2 - y1,
                linewidth=2, edgecolor='r', facecolor='none'
            )
            ax.add_patch(rect)

            # draw class name and score
            text = f"{CLASS_MAP[int(label.item())]} {score.item():.2f}"
            ax.text(
                x1, y1 - 4, text,
                fontsize=9, color='white',
                bbox=dict(facecolor='red', alpha=0.7, pad=2)
            )

        plt.axis('off')
        plt.show()

# Example usage:
visualize_predictions(val_ds, model, device, num_images=100, score_threshold=0.1)
# Out:
# {'boxes': tensor([[ 485.8267, 1568.6207, 1584.5928, 2647.1377],
#         [ 380.4666,  274.4360, 1900.1849, 2495.3972]], device='cuda:0'), 'labels': tensor([2, 2], device='cuda:0'), 'scores': tensor([0.9931, 0.0654], device='cuda:0')}
# {'boxes': tensor([[ 384.4527, 1100.7810, 1570.3075, 2219.8560]], device='cuda:0'), 'labels': tensor([2], device='cuda:0'), 'scores': tensor([0.1394], device='cuda:0')}
# {'boxes': tensor([[ 473.4296, 1417.3693, 1634.3771, 2763.3440]], device='cuda:0'), 'labels': tensor([3], device='cuda:0'), 'scores': tensor([0.9938], device='cuda:0')}
# {'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}
# {'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}
# {'boxes': tensor([[ 441.5658, 1408.6940, 1847.3231, 2879.6184]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9969], device='cuda:0')}
# {'boxes': tensor([[ 271.8131, 1145.2365, 1774.8097, 2794.9016]], device='cuda:0'), 'labels': tensor([2], device='cuda:0'), 'scores': tensor([0.2786], device='cuda:0')}
# {'boxes': tensor([[ 533.5924, 1141.8156, 1832.8882, 2576.7844]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.0841], device='cuda:0')}
# {'boxes': tensor([], device='cuda:0', size=(0, 4)), 'labels': tensor([], device='cuda:0', dtype=torch.int64), 'scores': tensor([], device='cuda:0')}
# {'boxes': tensor([[ 599.4545, 1351.8889, 1495.2336, 2503.4402]], device='cuda:0'), 'labels': tensor([1], device='cuda:0'), 'scores': tensor([0.9849], device='cuda:0')}
# {'boxes': tensor([[ 381.6888,  988.6083, 1358.8728, 1603.8779],
#         [ 397.9164,  965.0059, 1324.3325, 1515.7947]], device='cuda:0'), 'labels': tensor([2, 1], device='cuda:0'), 'scores': tensor([0.9787, 0.0534], device='cuda:0')}
# {'boxes': tensor([[ 479.1210, 1253.6584, 1777.5004, 2712.9021]], device='cuda:0'), 'labels': tensor([3], device='cuda:0'), 'scores': tensor([0.9894], device='cuda:0')}
# {'boxes': tensor([[1042.4304,  725.0974, 1995.3953, 1752.7017],
#         [1004.9484,  703.6287, 1949.8163, 1652.6576]], device='cuda:0'), 'labels': tensor([2, 1], device='cuda:0'), 'scores': tensor([0.9707, 0.0819], device='cuda:0')}
# {'boxes': tensor([[ 610.0326,  959.7462, 1987.2888, 2337.0645],
#         [ 451.9707,  953.4120, 1934.8208, 2235.5044],
#         [ 621.3393,  986.7929, 2062.5459, 2315.4292]], device='cuda:0'), 'labels': tensor([3, 1, 2], device='cuda:0'), 'scores': tensor([0.9705, 0.0910, 0.0659], device='cuda:0')}
# {'boxes': tensor([[ 490.7681, 1509.6685, 1811.2054, 2852.6086],
#         [ 921.4200,    0.0000, 2085.2664,  620.4113]], device='cuda:0'), 'labels': tensor([1, 2], device='cuda:0'), 'scores': tensor([0.9951, 0.0552], device='cuda:0')}
# {'boxes': tensor([[ 354.2611, 1465.2732, 1768.8623, 2647.8926],
#         [ 350.1960, 1471.4059, 1783.3186, 2621.4526]], device='cuda:0'), 'labels': tensor([2, 3], device='cuda:0'), 'scores': tensor([0.9700, 0.0554], device='cuda:0')}
# {'boxes': tensor([[ 777.3099,  984.4809, 1851.2013, 2287.8938]], device='cuda:0'), 'labels': tensor([2], device='cuda:0'), 'scores': tensor([0.9982], device='cuda:0')}
